# %% [markdown]
# # Substitution Matrices
#
# Let's create and store some common substitution matrices.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ### 1. DNA Transition/Transversion Matrix

# %%
S = pd.read_csv('dna_transition_transversion.csv',index_col=0)
S
# Out:
#      A    G    C    T
# A  2.0 -5.0 -7.0 -7.0
# G -5.0  2.0 -7.0 -7.0
# C -7.0 -7.0  2.0 -5.0
# T -7.0 -7.0 -5.0  2.0

# %% [markdown]
# ### 2. DNA Identity Matrix

# %%
S = pd.read_csv('dna_identity.csv',index_col=0)
S
# Out:
#      A    G    C    T
# A  1.0  0.0  0.0  0.0
# G  0.0  1.0  0.0  0.0
# C  0.0  0.0  1.0  0.0
# T  0.0  0.0  0.0  1.0

# %% [markdown]
# ### 3. BLOSUM 62

# %%
S = pd.read_csv('blosum62.csv',index_col=0)
S
# Out:
#     A   R   N   D   C   Q   E   G   H   I   L   K   M   F   P   S   T   W   Y  \
# A   4  -1  -2  -2   0  -1  -1   0  -2  -1  -1  -1  -1  -2  -1   1   0  -3  -2
# R  -1   5   0  -2  -3   1   0  -2   0  -3  -2   2  -1  -3  -2  -1  -1  -3  -2
# N  -2   0   6   1  -3   0   0   0   1  -3  -3   0  -2  -3  -2   1   0  -4  -2
# D  -2  -2   1   6  -3   0   2  -1  -1  -3  -4  -1  -3  -3  -1   0  -1  -4  -3
# C   0  -3  -3  -3   9  -3  -4  -3  -3  -1  -1  -3  -1  -2  -3  -1  -1  -2  -2
# Q  -1   1   0   0  -3   5   2  -2   0  -3  -2   1   0  -3  -1   0  -1  -2  -1
# E  -1   0   0   2  -4   2   5  -2   0  -3  -3   1  -2  -3  -1   0  -1  -3  -2
# G   0  -2   0  -1  -3  -2  -2   6  -2  -4  -4  -2  -3  -3  -2   0  -2  -2  -3
# H  -2   0   1  -1  -3   0   0  -2   8  -3  -3  -1  -2  -1  -2  -1  -2  -2   2
# I  -1  -3  -3  -3  -1  -3  -3  -4  -3   4   2  -3   1   0  -3  -2  -1  -3  -1
# L  -1  -2  -3  -4  -1  -2  -3  -4  -3   2   4  -2   2   0  -3  -2  -1  -2  -1
# ...

# %% [markdown]
# ### 4. BLOSUM 50

# %%
S = pd.read_csv('blosum50.csv',index_col=0)
S
# Out:
#    A  R  N  D   C  Q  E  G   H  I  L  K  M  F   P  S  T  W    Y  V
# A  5 -2 -1 -2  -1 -1 -1  0  -2 -1 -2 -1 -1 -3  -1  1  0   -3 -2  0
# R -2  7 -1 -2  -4  1  0 -3   0 -4 -3  3 -2 -3  -3 -1 -1   -3 -1 -3
# N -1 -1  7  2  -2  0  0  0   1 -3 -4  0 -2 -4  -2  1  0   -4 -2 -3
# D -2 -2  2  8  -4  0  2 -1  -1 -4 -4 -1 -4 -5  -1  0 -1   -5 -3 -4
# C -1 -4 -2 -4  13 -3 -3 -3  -3 -2 -2 -3 -2 -2  -4 -1 -1   -5 -3 -1
# Q -1  1  0  0  -3  7  2 -2   1 -3 -2  2  0 -4  -1  0 -1   -1 -1 -3
# E -1  0  0  2  -3  2  6 -3   0 -4 -3  1 -2 -3  -1 -1 -1   -3 -2 -3
# G  0 -3  0 -1  -3 -2 -3  8  -2 -4 -4 -2 -3 -4  -2  0 -2   -3 -3 -4
# H -2  0  1 -1  -3  1  0 -2  10 -4 -3  0 -1 -1  -2 -1 -2   -3  2 -4
# I -1 -4 -3 -4  -2 -3 -4 -4  -4  5  2 -3  2  0  -3 -3 -1   -3 -1  4
# L -2 -3 -4 -4  -2 -2 -3 -4  -3  2  5 -3  3  1  -4 -3 -1   -2 -1  1
# K -1  3  0 -1  -3  2  1 -2   0 -3 -3  6 -2 -4  -1  0 -1   -3 -2 -3
# M -1 -2 -2 -4  -2  0 -2 -3  -1  2  3 -2  7  0  -3 -2 -1   -1  0  1
# ...

# %% [markdown]
# ### 5. PAM250

# %%
S = pd.read_csv('pam250.csv',index_col=0)
S
# Out:
#     A   R   N   D   C   Q   E   G   H   I   L   K   M   F   P   S   T   W   Y  \
# A   2  -2   0   0  -2   0   0   1  -1  -1  -2  -1  -1  -3   1   1   1  -6  -3
# R  -2   6   0  -1  -4   1  -1  -3   2  -2  -3   3   0  -4   0   0  -1   2  -4
# N   0   0   2   2  -4   1   1   0   2  -2  -3   1  -2  -3   0   1   0  -4  -2
# D   0  -1   2   4  -5   2   3   1   1  -2  -4   0  -3  -6  -1   0   0  -7  -4
# C  -2  -4  -4  -5  12  -5  -5  -3  -3  -2  -6  -5  -5  -4  -3   0  -2  -8   0
# Q   0   1   1   2  -5   4   2  -1   3  -2  -2   1  -1  -5   0  -1  -1  -5  -4
# E   0  -1   1   3  -5   2   4   0   1  -2  -3   0  -2  -5  -1   0   0  -7  -4
# G   1  -3   0   1  -3  -1   0   5  -2  -3  -4  -2  -3  -5   0   1   0  -7  -5
# H  -1   2   2   1  -3   3   1  -2   6  -2  -2   0  -2  -2   0  -1  -1  -3   0
# I  -1  -2  -2  -2  -2  -2  -2  -3  -2   5   2  -2   2   1  -2  -1   0  -5  -1
# L  -2  -3  -3  -4  -6  -2  -3  -4  -2   2   6  -3   4   2  -3  -3  -2  -2  -1
# ...

# %% [markdown]
# ### 6. PAM100

# %%
S = pd.read_csv('pam100.csv',index_col=0)
S
# Out:
#     A   R   N   D   C   Q   E   G   H   I   L   K   M   F   P   S   T   W   Y  \
# A   4  -3  -1  -1  -3  -2   0   1  -3  -2  -3  -3  -2  -5   1   1   1  -7  -4
# R  -3   7  -2  -4  -5   1  -3  -5   1  -3  -5   2  -1  -6  -1  -1  -3   1  -6
# N  -1  -2   5   3  -5  -1   1  -1   2  -3  -4   1  -4  -5  -2   1   0  -5  -2
# D  -1  -4   3   5  -7   0   4  -1  -1  -4  -6  -1  -5  -8  -3  -1  -2  -9  -6
# C  -3  -5  -5  -7   9  -8  -8  -5  -4  -3  -8  -8  -7  -7  -4  -1  -4  -9  -1
# Q  -2   1  -1   0  -8   6   2  -3   3  -4  -2   0  -2  -7  -1  -2  -2  -7  -6
# E   0  -3   1   4  -8   2   5  -1  -1  -3  -5  -1  -4  -8  -2  -1  -2  -9  -5
# G   1  -5  -1  -1  -5  -3  -1   5  -4  -5  -6  -3  -4  -6  -2   0  -2  -9  -7
# H  -3   1   2  -1  -4   3  -1  -4   7  -4  -3  -2  -4  -3  -1  -2  -3  -4  -1
# I  -2  -3  -3  -4  -3  -4  -3  -5  -4   6   1  -3   1   0  -4  -3   0  -7  -3
# L  -3  -5  -4  -6  -8  -2  -5  -6  -3   1   6  -4   3   0  -4  -4  -3  -3  -3
# ...
